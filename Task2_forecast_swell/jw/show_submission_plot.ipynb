# %%
import pandas as pd
import matplotlib
# %matplotlib inline 
matplotlib.rc('font', family='AppleGothic')

plt.rcParams["figure.figsize"] = (20,75)

# %%
df = pd.read_excel('../../submission/2차/과제2_2차제출/(과제2)결과 제출 양식_수정_ttukbaegi3_v2.xlsx',skiprows=2)
df.set_index(df.columns[0],inplace=True)

df2 = pd.read_excel('../../submission/2차/과제2_2차제출 2/(과제2)결과 제출 양식_수정_ttukbaegi3_v2.xlsx',skiprows=2)
df2.set_index(df2.columns[0],inplace=True)

# df2 = pd.read_excel('../../submission/1차/(과제2) 결과 제출 양식_수정_ttukbaegi3.xlsx',skiprows=2)
# df2.set_index(df2.columns[0],inplace=True)

# %%
index = 0
for i in range(25):
    index = i*24
    plt.subplot(25,1,i+1)
    df.T[df.T.columns[i]].plot()
    df2.T[df2.T.columns[i]].plot()
