# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline

plt.rcParams['figure.figsize'] = (16,4)
plt.rcParams['font.family'] = 'AppleGothic'

# %%
import pandas as pd

# %%
df = pd.read_csv('./cli_train.tsv',sep='\t')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20010 entries, 0 to 20009
# Data columns (total 11 columns):
# 일자             20010 non-null int64
# time           20010 non-null object
# 식사내용           20010 non-null object
# 매출일자           20010 non-null float64
# 수량             20010 non-null float64
# 일시             20010 non-null object
# 평균기온(°C)       20010 non-null float64
# 최저기온(°C)       20010 non-null float64
# 최고기온(°C)       20010 non-null float64
# 강수 계속시간(hr)    20010 non-null float64
# 일강수량(mm)       20010 non-null float64
# dtypes: float64(7), int64(1), object(3)
# memory usage: 1.7+ MB

# %%
df['일자'] = df['일자'].astype(str)

# %%
df['time'].value_counts()
# Out:
# 저녁     5196
# 아침     5196
# 점심     5193
# 점심2    4425
# Name: time, dtype: int64

# %%
df[df['time']=='점심2'].sort_values('일자').head()
# Out:
#             일자 time                                               식사내용  \
# 1974  20050110  점심2   감자튀김(40),단무지,생선까스,쌀밥,야채샐러드,크림스프(경양식),포기김치,후르츠펀치,
# 1978  20050111  점심2                               귤,쌀밥,아구탕,오이소박이,포기김치,
# 1982  20050112  점심2  쇠고기스프(경양식),스위트피클,식혜,쌀밥,야채샐러드,으깬감자샐러드,치즈함박스테이크,...
# 1986  20050113  점심2                          계란탕,단무지.옥파,레몬차,쌀밥,자장면,잡채,
# 1990  20050114  점심2                              산채비빔밥,요구르트,포기김치,피홍합탕,
#
#             매출일자         수량          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  \
# 1974  20050110.0  10.830325  2005-01-10      -2.1      -7.7       2.7
# 1978  20050111.0  10.830325  2005-01-11      -0.3      -3.3       3.3
# 1982  20050112.0   6.353791  2005-01-12      -1.9      -5.7       2.3
# 1986  20050113.0  10.830325  2005-01-13      -1.2      -4.4       3.1
# 1990  20050114.0  10.830325  2005-01-14       0.7      -4.5       6.4
#
#       강수 계속시간(hr)  일강수량(mm)
# 1974          0.0       0.0
# 1978          0.0       0.0
# 1982          0.0       0.0
# ...

# %%
one_lunch_df = df.iloc[:1971].set_index('일자')
one_lunch_df.head()
# Out:
#          time                                               식사내용        매출일자  \
# 일자
# 20030301   아침  과일샐러드,닭죽,돈육마늘장조림,떡만두국,부추김무침,쌀밥,딸기잼(중),비엔나구이,스크...  20030301.0
# 20030301   저녁                       감자으깸샐러드,비프까스,스위트피클,쌀밥,옥수수스프,  20030301.0
# 20030301   점심                  골뱅이야채무침,새우맛살튀김,쌀밥(사무직),열무겉절이,칼국수,  20030301.0
# 20030302   아침  계란죽,곤약멸치조림,김치국,마카로니샐러드,쌀밥,오징어회무침,딸기잼(중),삶은계란,야...  20030302.0
# 20030302   저녁                         계란탕,단무지잔파무침,자장소스,잡채밥,탕수만두,  20030302.0
#
#                  수량          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  강수 계속시간(hr)  \
# 일자
# 20030301  37.472924  2003-03-01       6.1       4.5       8.0         9.25
# 20030301  19.566787  2003-03-01       6.1       4.5       8.0         9.25
# 20030301  31.191336  2003-03-01       6.1       4.5       8.0         9.25
# 20030302  36.101083  2003-03-02       9.5       3.7      15.1         0.00
# 20030302  21.949458  2003-03-02       9.5       3.7      15.1         0.00
#
#           일강수량(mm)
# 일자
# ...

# %%
two_lunch_df = df.iloc[1971:].set_index('일자')
two_lunch_df.head()
# Out:
#          time                                               식사내용        매출일자  \
# 일자
# 20050110   아침  쇠고기메추리알조림,쌀밥,야채죽,오이지무침,오징어콩나물찜,우유,포기김치,호박새우젓국,...  20050110.0
# 20050110   저녁            고등어김치찌개,땅콩흑콩조림,만두국,비빔된장,쌀밥,열무김치,참나물겉절이,  20050110.0
# 20050110   점심               귤,소방어무조림,숙주미나리나물,쌀밥,알타리김치,콩비지찌개,탕수육,  20050110.0
# 20050110  점심2   감자튀김(40),단무지,생선까스,쌀밥,야채샐러드,크림스프(경양식),포기김치,후르츠펀치,  20050110.0
# 20050111   아침  갈치구이,건취나물볶음,누룽지,도토리묵무침,쌀밥,우유,육개장,포기김치,당근스프(경양식...  20050111.0
#
#                  수량          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  강수 계속시간(hr)  \
# 일자
# 20050110  43.537906  2005-01-10      -2.1      -7.7       2.7          0.0
# 20050110  24.548736  2005-01-10      -2.1      -7.7       2.7          0.0
# 20050110  45.848375  2005-01-10      -2.1      -7.7       2.7          0.0
# 20050110  10.830325  2005-01-10      -2.1      -7.7       2.7          0.0
# 20050111  44.837545  2005-01-11      -0.3      -3.3       3.3          0.0
#
#           일강수량(mm)
# 일자
# ...

# %%
one_lunch_df[one_lunch_df['time']=='점심']['수량'].describe()
# Out:
# count    657.000000
# mean      43.871113
# std       13.448380
# min       16.389892
# 25%       30.108303
# 50%       48.231047
# 75%       53.429603
# max      134.223827
# Name: 수량, dtype: float64

# %%
one_lunch_df[one_lunch_df['time']=='점심']['수량'].plot()

# %%
np.argmax(one_lunch_df[one_lunch_df['time']=='점심']['수량'] > 130)
# Out:
# '20030722'

# %% [markdown]
# ### outlier

# %%
one_lunch_df.loc['20030722']
# Out:
#          time                                               식사내용        매출일자  \
# 일자
# 20030722   아침  가자미양념장구이,고추지무침,북어계란국,양송이피망볶음,여러가지야채,우유,콩죽,포기김치...  20030722.0
# 20030722   저녁          감자조림,쇠고기팽이버섯볶음,쌀밥,천사채샐러드,추어탕,포기김치2,햄계란부침,  20030722.0
# 20030722   점심     멸치볶음,미니돈까스,케찹소스,미역오이냉국,산채비빔밥,치킨너겟,포기김치2,후르츠펀치,  20030722.0
#
#                   수량          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  강수 계속시간(hr)  \
# 일자
# 20030722   45.631769  2003-07-22      22.3      20.8      23.7         17.5
# 20030722   21.949458  2003-07-22      22.3      20.8      23.7         17.5
# 20030722  134.223827  2003-07-22      22.3      20.8      23.7         17.5
#
#           일강수량(mm)
# 일자
# 20030722      11.5
# 20030722      11.5
# 20030722      11.5

# %%
two_lunch_df[two_lunch_df['time']=='점심']['수량'].describe()
# Out:
# count    4536.000000
# mean       24.944941
# std        11.576439
# min         3.321300
# 25%        15.090253
# 50%        23.826715
# 75%        33.862816
# max        75.379061
# Name: 수량, dtype: float64

# %%
two_lunch_df[two_lunch_df['time']=='점심']['수량'].plot()

# %%
two_lunch_df[two_lunch_df['time']=='점심2']['수량'].describe()
# Out:
# count    4425.000000
# mean       12.961162
# std         5.089186
# min         1.155235
# 25%         9.386282
# 50%        11.552347
# 75%        15.162455
# max        36.967509
# Name: 수량, dtype: float64

# %%
two_lunch_df[two_lunch_df['time']=='점심2']['수량'].plot()
